# %%
import pandas as pd

# %%
df = pd.read_csv('../final_internship_data.csv')

# %%
df.head()
# Out:
#     User ID          User Name       Driver Name Car Condition Weather  \
# 0  KHVrEVlD     Kimberly Adams        Amy Butler     Very Good   windy
# 1  lPxIuEri       Justin Tapia  Hannah Zimmerman     Excellent  cloudy
# 2  gsVN8JLS    Elizabeth Lopez    Amanda Jackson           Bad  stormy
# 3  9I7kWFgd      Steven Wilson          Amy Horn     Very Good  stormy
# 4  8QN5ZaGN  Alexander Andrews  Cassandra Larson           Bad  stormy
#
#    Traffic Condition                            key  fare_amount  \
# 0  Congested Traffic    2009-06-15 17:26:21.0000001          4.5
# 1       Flow Traffic    2010-01-05 16:52:16.0000002         16.9
# 2  Congested Traffic   2011-08-18 00:35:00.00000049          5.7
# 3       Flow Traffic    2012-04-21 04:30:42.0000001          7.7
# 4  Congested Traffic  2010-03-09 07:51:00.000000135          5.3
#
#        pickup_datetime  pickup_longitude  ...  month  weekday  year  \
# 0  2009-06-15 17:26:21         -1.288826  ...      6        0  2009
# ...

# %%
df.shape[1]
# Out:
# 26

# %%
df.shape[0]
# Out:
# 500000

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#     User ID          User Name       Driver Name Car Condition Weather  \
# 0  KHVrEVlD     Kimberly Adams        Amy Butler     Very Good   windy
# 1  lPxIuEri       Justin Tapia  Hannah Zimmerman     Excellent  cloudy
# 2  gsVN8JLS    Elizabeth Lopez    Amanda Jackson           Bad  stormy
# 3  9I7kWFgd      Steven Wilson          Amy Horn     Very Good  stormy
# 4  8QN5ZaGN  Alexander Andrews  Cassandra Larson           Bad  stormy
#
#    Traffic Condition                            key  fare_amount  \
# 0  Congested Traffic    2009-06-15 17:26:21.0000001          4.5
# 1       Flow Traffic    2010-01-05 16:52:16.0000002         16.9
# 2  Congested Traffic   2011-08-18 00:35:00.00000049          5.7
# 3       Flow Traffic    2012-04-21 04:30:42.0000001          7.7
# 4  Congested Traffic  2010-03-09 07:51:00.000000135          5.3
#
#        pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  500000.000000     500000.000000    500000.000000      499995.000000
# mean       11.358361         -1.265712         0.696740          -1.265755
# std         9.916617          0.206941         0.140909           0.205903
# min       -44.900000        -52.119764       -54.389440         -59.049665
# 25%         6.000000         -1.291405         0.710958          -1.291393
# 50%         8.500000         -1.291226         0.711268          -1.291197
# 75%        12.500000         -1.290970         0.711520          -1.290908
# max       500.000000         37.360538        29.724576           0.712985
#
#        dropoff_latitude  passenger_count           hour            day  \
# count     499995.000000    500000.000000  500000.000000  500000.000000
# mean           0.696675         1.683428      13.510834      15.684206
# std            0.128997         1.307395       6.511571       8.681066
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 26 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   User ID            500000 non-null  object
#  1   User Name          500000 non-null  object
#  2   Driver Name        500000 non-null  object
#  3   Car Condition      500000 non-null  object
#  4   Weather            500000 non-null  object
#  5   Traffic Condition  500000 non-null  object
#  6   key                500000 non-null  object
#  7   fare_amount        500000 non-null  float64
#  8   pickup_datetime    500000 non-null  object
#  9   pickup_longitude   500000 non-null  float64
#  10  pickup_latitude    500000 non-null  float64
#  11  dropoff_longitude  499995 non-null  float64
#  12  dropoff_latitude   499995 non-null  float64
#  13  passenger_count    500000 non-null  int64
#  14  hour               500000 non-null  int64
# ...

# %% [markdown]
# Data Preprocessing

# %% [markdown]
# 1. Handle Date to datetime instead of object

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

# %% [markdown]
# 2. See Nulls

# %%
df.isna().sum()
# Out:
# User ID              0
# User Name            0
# Driver Name          0
# Car Condition        0
# Weather              0
# Traffic Condition    0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    5
# dropoff_latitude     5
# passenger_count      0
# hour                 0
# day                  0
# month                0
# weekday              0
# year                 0
# jfk_dist             5
# ewr_dist             5
# lga_dist             5
# sol_dist             5
# nyc_dist             5
# distance             5
# bearing              5
# dtype: int64

# %%
df[df['dropoff_longitude'].isna()]
# Out:
#          User ID       User Name     Driver Name Car Condition Weather  \
# 120227  BOLML7gg       Carol Kim      John Scott     Very Good   rainy
# 245696  AA838qgm      Mark Jones  Christy Taylor           Bad   windy
# 340533  BqrlHUr2  Joshua Mullins      Sarah Khan     Excellent  cloudy
# 428108  rL4WTHGq   Richard Brown   Rachel Miller     Very Good  cloudy
# 471472  tKIOKS8Y      Larry Wade  Howard Jackson          Good   windy
#
#         Traffic Condition                           key  fare_amount  \
# 120227      Dense Traffic  2012-12-11 12:57:00.00000013         12.5
# 245696      Dense Traffic   2013-03-21 18:07:07.0000001         86.5
# 340533      Dense Traffic  2012-12-11 12:50:52.00000010         27.5
# 428108       Flow Traffic   2011-09-08 09:12:52.0000001         11.8
# 471472  Congested Traffic   2012-12-11 12:34:20.0000006          7.8
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# ...

# %% [markdown]
# The problem is with those specific 5 records

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.isna().sum()
# Out:
# User ID              0
# User Name            0
# Driver Name          0
# Car Condition        0
# Weather              0
# Traffic Condition    0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# hour                 0
# day                  0
# month                0
# weekday              0
# year                 0
# jfk_dist             0
# ewr_dist             0
# lga_dist             0
# sol_dist             0
# nyc_dist             0
# distance             0
# bearing              0
# dtype: int64

# %% [markdown]
# 2. Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 3. Categorical Columns

# %%
df.columns
# Out:
# Index(['User ID', 'User Name', 'Driver Name', 'Car Condition', 'Weather',
#        'Traffic Condition', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'hour', 'day', 'month',
#        'weekday', 'year', 'jfk_dist', 'ewr_dist', 'lga_dist', 'sol_dist',
#        'nyc_dist', 'distance', 'bearing'],
#       dtype='object')

# %%
categorical_cols = ['User ID', 'User Name', 'Driver Name', 'Car Condition', 'Weather',
       'Traffic Condition', 'key', 'pickup_datetime']

# %%
for col in categorical_cols:
    df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 26 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   User ID            500000 non-null  category
#  1   User Name          500000 non-null  category
#  2   Driver Name        500000 non-null  category
#  3   Car Condition      500000 non-null  category
#  4   Weather            500000 non-null  category
#  5   Traffic Condition  500000 non-null  category
#  6   key                500000 non-null  category
#  7   fare_amount        500000 non-null  float64
#  8   pickup_datetime    500000 non-null  category
#  9   pickup_longitude   500000 non-null  float64
#  10  pickup_latitude    500000 non-null  float64
#  11  dropoff_longitude  500000 non-null  float64
#  12  dropoff_latitude   500000 non-null  float64
#  13  passenger_count    500000 non-null  int64
#  14  hour               500000 non-null  int64
# ...

# %% [markdown]
# -- Detect & Handle Outliers --

# %%
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column] < lower) | (df[column] > upper)]

# %%
outliers_fare = detect_outliers_iqr(df, 'fare_amount')
print(f"Fare outliers: {len(outliers_fare)}")
# Out:
# Fare outliers: 43331

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
sns.boxplot(x=df['fare_amount'])
plt.title("Fare Amount Outliers")
plt.show()

# %%
outliers_distance = detect_outliers_iqr(df, 'distance')
print(f"Distance outliers: {len(outliers_distance)}")
# Out:
# Distance outliers: 41928

# %%
sns.boxplot(x=df['distance'])
# Out:
# <Axes: xlabel='distance'>

# %%
outliers_passenger_count = detect_outliers_iqr(df, 'passenger_count')
print(f"passenger_count outliers: {len(outliers_passenger_count)}")
# Out:
# passenger_count outliers: 56526

# %%
sns.boxplot(x=df['passenger_count'])
# Out:
# <Axes: xlabel='passenger_count'>

# %%
outliers_Traffic_Condition = detect_outliers_iqr(df, 'Traffic Condition')
print(f"Traffic Condition outliers: {len(outliers_Traffic_Condition)}") # error as it needs encoding and I did it below so will redo outliers detection for this column after encoding in correlation section
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 outliers_Traffic_Condition = detect_outliers_iqr(df, 'Traffic Condition')
#       2 print(f"Traffic Condition outliers: {len(outliers_Traffic_Condition)}")
#
# Cell In[55], line 2, in detect_outliers_iqr(df, column)
#       1 def detect_outliers_iqr(df, column):
# ----> 2     Q1 = df[column].quantile(0.25)
#       3     Q3 = df[column].quantile(0.75)
#       4     IQR = Q3 - Q1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:2887, in Series.quantile(self, q, interpolation)
#    2883 # We dispatch to DataFrame so that core.internals only has to worry
#    2884 #  about 2D cases.
#    2885 df = self.to_frame()
# -> 2887 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2888 if result.ndim == 2:
#    2889     result = result.iloc[:, 0]
#
# ...

# %%
def cap_outliers(df, column):
    lower = df[column].quantile(0.01)
    upper = df[column].quantile(0.99)
    df[column] = df[column].clip(lower, upper)
    return df

df = cap_outliers(df, 'fare_amount')
df = cap_outliers(df, 'distance')

# %%
sns.boxplot(x=df['fare_amount'])
# Out:
# <Axes: xlabel='fare_amount'>

# %%
sns.boxplot(x=df['distance'])
# Out:
# <Axes: xlabel='distance'>

# %% [markdown]
# 4. Correlation

# %%
df[['distance', 'fare_amount']].corr()
# Out:
#              distance  fare_amount
# distance      1.00000      0.84208
# fare_amount   0.84208      1.00000

# %%
df.groupby('Traffic Condition')[['distance', 'fare_amount']].mean()
# Out:
# C:\Users\Malak\AppData\Local\Temp\ipykernel_56012\4029926163.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Traffic Condition')[['distance', 'fare_amount']].mean()
#                    distance  fare_amount
# Traffic Condition
# Congested Traffic  3.294992    11.269275
# Dense Traffic      3.285212    11.249786
# Flow Traffic       3.281835    11.219721

# %%
df['traffic_encoded'] = df['Traffic Condition'].astype('category').cat.codes


corr_matrix = df[['traffic_encoded', 'distance', 'fare_amount']].corr()

# %%
outliers_traffic_encoded = detect_outliers_iqr(df, 'traffic_encoded')
print(f"Traffic Condition outliers: {len(outliers_traffic_encoded)}")
# Out:
# Traffic Condition outliers: 0

# %%
df['traffic_encoded'].value_counts()
# Out:
# traffic_encoded
# 0    166233
# 1    166005
# 2    165966
# Name: count, dtype: int64

# %%
df['Traffic Condition'].value_counts()
# Out:
# Traffic Condition
# Congested Traffic    166233
# Dense Traffic        166005
# Flow Traffic         165966
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap: Traffic, Distance, Fare')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.barplot(data=df, x='fare_amount', y='Traffic Condition')
plt.title('Fare Amount by Traffic Condition')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#     User ID          User Name       Driver Name Car Condition Weather  \
# 0  KHVrEVlD     Kimberly Adams        Amy Butler     Very Good   windy
# 1  lPxIuEri       Justin Tapia  Hannah Zimmerman     Excellent  cloudy
# 2  gsVN8JLS    Elizabeth Lopez    Amanda Jackson           Bad  stormy
# 3  9I7kWFgd      Steven Wilson          Amy Horn     Very Good  stormy
# 4  8QN5ZaGN  Alexander Andrews  Cassandra Larson           Bad  stormy
#
#    Traffic Condition                            key  fare_amount  \
# 0  Congested Traffic    2009-06-15 17:26:21.0000001          4.5
# 1       Flow Traffic    2010-01-05 16:52:16.0000002         16.9
# 2  Congested Traffic   2011-08-18 00:35:00.00000049          5.7
# 3       Flow Traffic    2012-04-21 04:30:42.0000001          7.7
# 4  Congested Traffic  2010-03-09 07:51:00.000000135          5.3
#
#       pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# ...

# %% [markdown]
# 1. Total Trips

# %%
print("Total trips:", df.shape[0])
# Out:
# Total trips: 500000

# %% [markdown]
# 2. Fare Amount Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['fare_amount'], bins=50, kde=True)
plt.title('Distribution of Fare Amounts')
plt.xlabel('Fare Amout')
plt.ylabel('Number of Trips')
plt.show()

# %% [markdown]
# 3. Average of Dustance and Fare with Year

# %%
yearly = df.groupby('year')[['fare_amount', 'distance']].mean().reset_index()

plt.figure(figsize=(10,5))
sns.lineplot(data=yearly, x='year', y='fare_amount', label='Avg Fare')
sns.lineplot(data=yearly, x='year', y='distance', label='Avg Distance')
plt.title('Average Fare and Distance per Year')
plt.show()

# %% [markdown]
# 4. Most Popular Hours

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='hour', data=df)
plt.title('Most Popular Hours')
plt.xlabel('Hour of Day')
plt.ylabel('Trip Count')
plt.show()

# %% [markdown]
# 5. Highest time of day?

# %%
df['time_of_day'] = pd.cut(df['hour'],
                           bins=[-1, 6, 12, 17, 21, 24],
                           labels=['Late Night', 'Morning', 'Afternoon', 'Evening', 'Night'])

plt.figure(figsize=(8,5))
sns.barplot(x='time_of_day', y='fare_amount', data=df)
plt.title('Fare Amounts by Time of Day')
plt.show()

# %% [markdown]
# 6. Does weather affect fare?

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Weather', y='fare_amount', data=df)
plt.title('Fare Amounts by Weather Condition')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# CATEGORICAL INSIGHTS

# %% [markdown]
# 1. Common Car Conditions

# %%
plt.figure(figsize=(6,4))
df['Car Condition'].value_counts().plot(kind='bar')
plt.title('Car Condition Distribution')
plt.ylabel('Number of Trips')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# 2. Effect of Traffic on fare as we got before

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Traffic Condition', y='fare_amount', data=df)
plt.title('Fare by Traffic Condition')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# 3. Effect of Weather on number of Passengers

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Weather', y='passenger_count', data=df)
plt.title('Passenger Count by Weather')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# GEOGRAPHICAL INSIGHTS!! msh fahma lsa leh tl3t kda

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='pickup_longitude', y='pickup_latitude', data=df.sample(10000), s=1)
plt.title('Pickup Locations')
plt.show()

# %% [markdown]
# Some Random Relationships for exploring

# %% [markdown]
# 1. Traffic with distance

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Traffic Condition', y='distance', data=df)
plt.title('Distance by Traffic Condition')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# 2. fare with passengers count

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='passenger_count', y='fare_amount', data=df)
plt.title('Fare Amount by Passenger Count')
plt.show()

# %% [markdown]
# 3. fare with distance

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='distance', y='fare_amount', data=df, alpha=0.3)
plt.title('Fare Amount vs Distance')
plt.xlabel('Distance by km')
plt.ylabel('Fare')
plt.show()
